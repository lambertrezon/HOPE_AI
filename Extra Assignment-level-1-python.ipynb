# %%
print("HOPE AI ")
# Out:
# HOPE AI

# %%
name = input("Enter your institute name : ")
print(f"\rEnter your institute name : {name}", end="")
# Out:
# Enter your institute name? : sa
# Enter your institute name? : sa

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
school = input("Enter your school name: ")
degree = input("Enter your degree: ")
print("--------------Result--------------")
print(f"\rEnter your name: {name} \nEnter your age: {age} \nEnter your school name: {school} \nEnter your degree: {degree}")
# Out:
# Enter your name: rezon
# Enter your age: 10
# Enter your school name: sks
# Enter your degree: ksj
# --------------Result--------------
# Enter your name: rezon
# Enter your age: 10
# Enter your school name: sks
# Enter your degree: ksj

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
add = num1 + num2
print(f"Addition = {add}")
# Out:
# Enter value for num1: 10
# Enter value for num2: 20
# add = 30

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
sub = num1 - num2
print(f"Subtraction = {sub}")
# Out:
# Enter value for num1: 20
# Enter value for num2: 10
# Subtraction = 10

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
mul = num1 * num2
print(f"Multiplication = {mul}")
# Out:
# Enter value for num1: 2
# Enter value for num2: 5
# Multiplication 10

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
float_div = num1 / num2
print(f"Division = {float_div}")
# Out:
# Enter value for num1: 10
# Enter value for num2: 2
# Division = 5.0

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
mod = num1 % num2
print(f"Modulo = {mod}")
# Out:
# Enter value for num1: 10
# Enter value for num2: 2
# Modulo 0

# %%
num1 = int(input("Enter value for num1: "))
num2 = int(input("Enter value for num2: "))
power = num1 ** num2
print(f"Power = {power}")
# Out:
# Enter value for num1: 2
# Enter value for num2: 2
# Power = 4
