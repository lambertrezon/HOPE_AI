# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

dataset = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/HOPE AI/WEEK-4.1-CLASSIFICATION/2.ASSIGNMENT/CKD.csv")
dataset

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/HOPE AI/WEEK-4.1-CLASSIFICATION/2.ASSIGNMENT/CKD.csv")
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.dropna()

indep=dataset[['age','bp','sc']]
dep=dataset['classification_yes']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['gini','entropy'],'n_estimators':[10,100],'max_features':['sqrt','log2']}

grid = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train, y_train)

from sklearn.metrics import confusion_matrix, classification_report, f1_score

pred = grid.predict(X_test)

print("F1:", f1_score(y_test,pred,average='weighted'))

age_input=float(input("Age:"))
bp_input=float(input("BP:"))
sc_input=float(input("Serum Creatinine:"))

Future_Prediction=grid.predict([[age_input,bp_input,sc_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Mounted at /content/gdrive
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# F1: 0.8870014821030976
# Age:20
