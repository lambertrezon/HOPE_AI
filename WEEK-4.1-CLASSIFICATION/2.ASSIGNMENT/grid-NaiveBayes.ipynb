# %%
from google.colab import drive
drive.mount('/content/gdrive')

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# !ls /content/gdrive/MyDrive/'Colab Notebooks'/'CKD'

dataset = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/HOPE AI/WEEK-4.1-CLASSIFICATION/2.ASSIGNMENT/CKD.csv")
dataset

#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Reading the Dataset
dataset = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/HOPE AI/WEEK-4.1-CLASSIFICATION/2.ASSIGNMENT/CKD.csv")
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

dataset=dataset.dropna()

dataset

# Selecting only 3 features
indep=dataset[['age','bp','sc']]
dep=dataset['classification_yes']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Naive Bayes
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV

param_grid = {
    'var_smoothing': [1e-09, 1e-08, 1e-07, 1e-06]
}

grid = GridSearchCV(GaussianNB(), param_grid, refit = True, verbose = 3, n_jobs=-1, scoring='f1_weighted')

# fitting the model for grid search
grid.fit(X_train, y_train)

re=grid.cv_results_
grid_predictions = grid.predict(X_test)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')

print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)

print("The confusion Matrix:\n",cm)
print("The report:\n",clf_report)

table=pd.DataFrame.from_dict(re)
table

# Manual Inputs (same style as your example)
age_input=float(input("Age:"))
bp_input=float(input("BP:"))
sc_input=float(input("Serum Creatinine:"))

Future_Prediction=grid.predict([[age_input,bp_input,sc_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Mounted at /content/gdrive
# ls: cannot access '/content/gdrive/MyDrive/Colab Notebooks/CKD': No such file or directory
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# The f1_macro value for best parameter {'var_smoothing': 1e-09}: 0.7605416255571055
# The confusion Matrix:
#  [[49  2]
#  [30 52]]
# The report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.96      0.75        51
#            1       0.96      0.63      0.76        82
#
#     accuracy                           0.76       133
#    macro avg       0.79      0.80      0.76       133
# weighted avg       0.83      0.76      0.76       133
#
# Age:20
# BP:120
# Serum Creatinine:0.9
# Future_Prediction=[1]
