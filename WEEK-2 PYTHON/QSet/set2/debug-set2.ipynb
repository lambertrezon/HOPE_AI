# %%
#1.Find the error in the following Python code:
#ans:Issue: Math should be lowercase as math.


import math
print(math.sqrt(16))

# %%
#2.Find the error in the following Python code:
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()

# %%
#3.x = 5 #ans:Issue: = is an assignment operator; == is needed for comparison.

x = 5
if x == 10:
    print("x is 10")

# %%
#4.
#ans:Issue: .sort() modifies the list in place and returns None.


numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)

# %%
#5 ans:Issue: The function does not return a value explicitly.

def square(n):
    return n * n

print(square(4))

# %%
#6  ans:Issue: Tuples are immutable and cannot be modified.
#my_tuple = (1, 2, 3)
#my_tuple[1] = 5
my_tuple = (1, 5, 3)  # Create a new tuple

# %%
#7. #ans:Issue: The format placeholders are missing a required argument.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
#ans:Issue: is checks for object identity, not value equality
if a == b:
    print("Lists are equal")

# %%
#9 ans:Issue: The range(5, 1) does not produce any numbers because the default step is +1.
for i in range(5, 1, -1):  # Step should be negative to decrement
    print(i)
