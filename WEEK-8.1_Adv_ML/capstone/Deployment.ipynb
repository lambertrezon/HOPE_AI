# %%
from google.colab import drive
drive.mount('/content/gdrive')

import warnings
warnings.filterwarnings("ignore")

import pickle
import numpy as np
from sklearn.preprocessing import StandardScaler

fileloc="/content/gdrive/MyDrive/Colab Notebooks/HOPE AI/WEEK-8.1_Adv_ML/capstone/"

loaded_model = pickle.load(open(fileloc + "finalized_model_random.sav", "rb"))

scaler = pickle.load(open(fileloc + "scaler.sav", "rb"))

sample = np.array([[
    1580,
    0.35,
    0.28,
    0.82,
    0.02,
    0.03,
    45,
    840,
    72,
    38,
    0,
    0
]])
scaler = StandardScaler()
sample = scaler.fit_transform(sample)

prediction = loaded_model.predict(sample)

print("Predicted Steel Strength:", prediction[0])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Predicted Steel Strength: 417.1052
