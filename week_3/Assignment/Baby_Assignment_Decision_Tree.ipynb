# %% [markdown]
# Decision Tree

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls /content/drive/MyDrive/Colab\ Notebooks/'HOPE AI'/WEEK-3-ML/1.Traditional_way/6.Baby_Assignment/
# Out:
# 6_Baby_Assignment_Decision_Tree.ipynb    6_Baby_Assignment_SVM.ipynb
# 6_Baby_Assignment.ipynb                  insurance_pre.csv
# 6_Baby_Assignment_Random_Forest.ipynb    Regression_Assignment.gdoc
# 6_Baby_Assignment_Simple_Multiple.ipynb  Regression_Assignment.pdf

# %%
import pandas as pd
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HOPE AI/WEEK-3-ML/1.Traditional_way/6.Baby_Assignment/insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=1)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
x_train
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 1163   18         0  28.215         0           0
# 196    39         0  32.800         0           0
# 438    52         0  46.750         5           0
# 183    44         0  26.410         0           0
# 1298   33         1  27.455         2           0
# ...   ...       ...     ...       ...         ...
# 763    27         1  26.030         0           0
# 835    42         1  35.970         2           0
# 1216   40         1  25.080         0           0
# 559    19         1  35.530         0           0
# 684    33         0  18.500         1           0
#
# [936 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor

# %%
from sklearn.metrics import r2_score
criteria = ['squared_error', 'absolute_error', 'friedman_mse']
max_features_list = ['auto', 'sqrt', 'log2']
splitters = ['best', 'random']
results = []
sl_no = 1

for criterion in criteria:
    for max_features in max_features_list:
        for splitter in splitters:
            try:
                model = DecisionTreeRegressor(
                    criterion=criterion,
                    max_features=max_features,
                    splitter=splitter
                   # random_state=42
                )

                model.fit(x_train, y_train)
                y_pred = model.predict(x_test)

                r_value = r2_score(y_test, y_pred)

                results.append({
                    "SL.NO": sl_no,
                    "CRITERION": criterion,
                    "MAX FEATURES": max_features,
                    "SPLITTER": splitter,
                    "R VALUE": round(r_value, 4)
                })

                sl_no += 1

            except:
                pass
df_dt = pd.DataFrame(results)

print(df_dt.to_string(index=False))
# Out:
#  SL.NO      CRITERION MAX FEATURES SPLITTER  R VALUE
#      1  squared_error         sqrt     best   0.6862
#      2  squared_error         sqrt   random   0.6914
#      3  squared_error         log2     best   0.7387
#      4  squared_error         log2   random   0.6960
#      5 absolute_error         sqrt     best   0.6751
#      6 absolute_error         sqrt   random   0.6530
#      7 absolute_error         log2     best   0.7185
#      8 absolute_error         log2   random   0.7190
#      9   friedman_mse         sqrt     best   0.6878
#     10   friedman_mse         sqrt   random   0.7196
#     11   friedman_mse         log2     best   0.7090
#     12   friedman_mse         log2   random   0.7153

# %%
best_row = df_dt.loc[df_dt["R VALUE"].idxmax()]
best_row
# Out:
# SL.NO                       3
# CRITERION       squared_error
# MAX FEATURES             log2
# SPLITTER                 best
# R VALUE                0.7387
# Name: 2, dtype: object
