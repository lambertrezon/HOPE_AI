# %% [markdown]
# Support Vector Regression

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
ls /content/drive/MyDrive/Colab\ Notebooks/'HOPE AI'/WEEK-3-ML/1.Traditional_way/6.Baby_Assignment/

# %%
import pandas as pd
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HOPE AI/WEEK-3-ML/1.Traditional_way/6.Baby_Assignment/insurance_pre.csv")

# %%
dataset

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=1)

# %%
dataset

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.5330973 , -0.97676557, -0.40713453, -0.89833872, -0.50466988],
#        [-0.03364163, -0.97676557,  0.32855417, -0.89833872, -0.50466988],
#        [ 0.89459283, -0.97676557,  2.56690911,  3.25603402, -0.50466988],
#        ...,
#        [ 0.03776102,  1.02378711, -0.91016269, -0.89833872, -0.50466988],
#        [-1.46169465,  1.02378711,  0.76659782, -0.89833872, -0.50466988],
#        [-0.46205754, -0.97676557, -1.96596021, -0.06746417, -0.50466988]])

# %%
from sklearn.svm import SVR
regressor = SVR(kernel="rbf",C=1000)
regressor.fit(x_train,y_train)

# %%
regressor.intercept_
# Out:
# array([14948.96194087])

# %%
regressor.n_support_
# Out:
# array([936], dtype=int32)

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8102064851758545

# %%
kernels = ['linear', 'rbf', 'poly', 'sigmoid']
C_values = [10, 100, 500, 1000, 2000, 3000]

results = []

for i, C in enumerate(C_values, start=1):
    row = {
        "S.NO": i,
        "HYPER PARAMETER": f"C{C}"
    }

    for kernel in kernels:
        model = SVR(kernel=kernel, C=C)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        r_value = r2_score(y_test, y_pred)
        row[kernel.upper()] = round(r_value, 4)

    results.append(row)


df = pd.DataFrame(results)
print (df)
# Out:
#    S.NO HYPER PARAMETER  LINEAR     RBF    POLY  SIGMOID
# 0     1             C10  0.4625 -0.0323  0.0387   0.0393
# 1     2            C100  0.6289  0.3200  0.6180   0.5276
# 2     3            C500  0.7631  0.6643  0.8264   0.4446
# 3     4           C1000  0.7649  0.8102  0.8566   0.2875
# 4     5           C2000  0.7440  0.8548  0.8606  -0.5940
# 5     6           C3000  0.7414  0.8663  0.8599  -2.1244
